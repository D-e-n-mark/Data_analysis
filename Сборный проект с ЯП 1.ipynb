# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# Привет. На данном этапе мои замечания будут выглядеть таким образом:
#
# <h2> Комментарий ревьюера VERS#3 <a class="tocSkip"> </h2>

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# Привет. Для того чтобы не создалась путаница я буду вставлять номер версии проверки в комментарии и на данном этапе мои замечания будут выглядеть таким образом:
#
# <h2> Комментарий ревьюера VERS#2 <a class="tocSkip"> </h2>
#
# Ты также можешь реагировать на мои комментарии своими, выделяя их цветом отличным от моего и маркируя версию 😉.

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b>Руслан, привет!👋</b>
#
# Это Юлия Булекова, я буду ревьюером твоего проекта. Ты можешь обращаться ко мне на "ты"😏 Надеюсь, тебя также не смутит, если я буду обращаться к тебе на "ты", но если это неудобно, обязательно скажи об этом!
#
# Пожалуйста, не удаляй мои комментарии, они будут особенно полезны для нашей работы в случае повторной проверки проекта.
#
#
#
# Ты можешь найти мои комментарии, обозначенные <font color='green'>зеленым</font>, <font color='gold'>желтым</font> и <font color='red'>красным</font> цветами, например:
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> В случае, если решение на отдельном шаге является полностью правильным.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b> В случае, когда решение на отдельном шаге станет еще лучше, если внести небольшие коррективы.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
#  В случае, когда решение на отдельном шаге требует существенной переработки и внесения правок. Напоминаю, что проект не может быть принят с первого раза, если ревью содержит комментарии, рекомендующие доработать шаги.
# </div>
#
# Увидев у тебя неточность, в первый раз я лишь укажу на ее наличие и дам тебе возможность самому найти и исправить ее. На реальной работе твой руководитель будет поступать также, и я пытаюсь подготовить тебя именно к работе аналитиком. Но если ты пока не справишься с такой задачей - при следующей проверке я дам более точную подсказку!🤓
#
#
# Предлагаю работать над проектом в диалоге: если ты хочешь ответить на мои комментарии — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии вот так:
#
# <div class="alert alert-info">
# <h2> Комментарий студента<a class="tocSkip"></h2>
#
# Тут текст
# </div>
#
#
# Всё это поможет выполнить повторную проверку твоего проекта оперативнее.

# %% [markdown]
# ### Выявление закономерностей, определяющих успешность игры для дальнейшего планирования рекламной кампании.
#
# На вход мы получили исторические данные о продаже игр из открытых источников. Нашей задачей является выявление закономерностей, определяющих успешность игры.
#
#
# # Инструкция по выполнению проекта
#
# ### Шаг 1. Откройте файл с данными и изучите общую информацию
# * [Откройте файл с данными и изучите общую информацию](#p1s1)
#
# ### Шаг 2. Подготовьте данные
# * [Замените названия столбцов (приведите к нижнему регистру)](#p2s1)
# * [Преобразуйте данные в нужные типы. Опишите, в каких столбцах заменили тип данных и почему](#p2s2)
# * Обработайте пропуски при необходимости:
#     * Объясните, почему заполнили пропуски определённым образом или почему [не стали это делать](#let_Nan_be)
#     * [Опишите причины, которые могли привести к пропускам](#possible_nan_reasons)
#     * [Обратите внимание на аббревиатуру 'tbd' в столбце с оценкой пользователей. Отдельно разберите это значение и опишите, как его обработать](#tbd)
# * [Посчитайте суммарные продажи во всех регионах и запишите их в отдельный столбец.](#sum_sale)
#
# ### Шаг 3. Проведите исследовательский анализ данных
# * [Посмотрите, сколько игр выпускалось в разные годы. Важны ли данные за все периоды?](#p3s1)
# * [Посмотрите, как менялись продажи по платформам. Выберите платформы с наибольшими суммарными продажами и постройте   распределение по годам. За какой характерный срок появляются новые и исчезают старые платформы?](#p3s2)
# * [Возьмите данные за соответствующий актуальный период. Актуальный период определите самостоятельно в результате исследования предыдущих вопросов. Основной фактор — эти данные помогут построить прогноз на 2017 год.](#p3s3)
# * Не учитывайте в работе данные за предыдущие годы.
# * [Какие платформы лидируют по продажам, растут или падают? Выберите несколько потенциально прибыльных платформ.](#p3s4)
# * [Постройте график «ящик с усами» по глобальным продажам игр в разбивке по платформам. Опишите результат.](#p3s5)
# * [Посмотрите, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Постройте диаграмму рассеяния и посчитайте корреляцию между отзывами и продажами. Сформулируйте выводы.](#p3s6)
# * [Соотнесите выводы с продажами игр на других платформах.](#p3s7)
# * [Посмотрите на общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с высокими и низкими продажами?](#p3s8)
#
# ### Шаг 4. Составьте портрет пользователя каждого региона
# Определите для пользователя каждого региона (NA, EU, JP):
# * [Самые популярные платформы (топ-5). Опишите различия в долях продаж.](#p4s1)
# * [Самые популярные жанры (топ-5). Поясните разницу.](#p4s2)
# * [Влияет ли рейтинг ESRB на продажи в отдельном регионе?](#p4s3)
#
# ### Шаг 5. Проверьте гипотезы
# * [Средние пользовательские рейтинги платформ Xbox One и PC одинаковые;](#p5s1)
# * [Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные.
# Задайте самостоятельно пороговое значение alpha.](#p5s2)
# Поясните:
# * [Как вы сформулировали нулевую и альтернативную гипотезы;](#p5s3)
# * [Какой критерий применили для проверки гипотез и почему.](#p5s4)
#
# ### Шаг 6. Напишите общий вывод

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера VERS#1 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Здорово, что интерактивное оглавление и краткое описание проекта добавлены в работу.👌

# %% [markdown]
# <a id='p1s1'></a>
# ## Откройте файл с данными и изучите общую информацию
# ### Импортируем все необходимые для работы библиотеки

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import plotly.express as px
from matplotlib import rcParams
from scipy import stats as st
import warnings 
warnings.filterwarnings("ignore")

# %%
from PIL import Image
import requests
from io import BytesIO

# %% [markdown]
# **Подгрузим датафрейм**

# %%
try:    
    initial_games = pd.read_csv('/datasets/games.csv')
except: 
    initial_games = pd.read_csv('https://code.s3.yandex.net/datasets/games.csv')
    
games = initial_games # понадобится для сравнения размера измененного датафрейма с исходным

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера VERS#1 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Отличный подход - указывать несколько путей для подгрузки файла🙌

# %% [markdown]
# **Функция для визуализации пропусков в данных**

# %%
def vis_nan(df):
    # вывод информации о пропусках в процентах по каждому столбцу
    for col in df.columns:
        pct_missing = np.mean(df[col].isnull())
        print('{} - {}%'.format(col, round(pct_missing*100)))
    
    # визуализация пропущенных данных на хитмэпе
    colours = ['black', '#b4fa4b'] 
    fig, ax = plt.subplots(figsize=(12,12))
    sns.heatmap(df.isnull(), yticklabels=False, cmap=sns.color_palette(colours))
    
    # параметры для значений легенды 
    colorbar = ax.collections[0].colorbar
    colorbar.set_ticks([1/4,3/4])
    colorbar.set_ticklabels(['Есть данные','Нет данныех'])

# %% [markdown]
# **Функция для вывода всей общей информации**

# %%
def gen_info(df):
    return display(df.sample(10)), \
    display(df.describe()), \
    display(df.info()), \
    display(df.shape), \
    display(vis_nan(df))

# %% [markdown]
# **Функция для подсчета потерь в данных в сравнении с исходным датафреймом**

# %%
def data_loss():
    percentage = ((games.shape[0] / initial_games.shape[0]) * 100)
    return round(percentage, 3)

# %% [markdown]
# **Функция для подсчета пропусков в конкретном столбце**

# %%
def nan_count(col):
    return games[col].isna().sum()

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера VERS#1 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Здесь также выполнен обстоятельный подход к работе, а именно создание функции в начале проекта для получения общей информации по датасету👏

# %%
gen_info(games)
# Out:
#                                          Name Platform  Year_of_Release  \
# 9970                            Madden NFL 17      PS3           2016.0
# 10985  MX SuperFly featuring Ricky Carmichael       GC           2002.0
# 13997                        Ragnarok Odyssey      PS3           2014.0
# 1886                            Densha De Go!       PS           1997.0
# 5545                            EA Playground       DS           2007.0
# 3150                    Football Manager 2014       PC           2013.0
# 8238     Kekkaishi: Karasumori Ayakashi Kidan       DS           2007.0
# 11462              Major League Baseball 2K11       PC           2011.0
# 4996                 SD Gundam G Generation-F       PS           2000.0
# 8193                          Velvet Assassin     X360           2009.0
#
#               Genre  NA_sales  EU_sales  JP_sales  Other_sales  Critic_Score  \
# 9970         Sports      0.07      0.02      0.00         0.02           NaN
# ...

# %% [markdown]
# Столбцы с наибольшей потерей данных `Critic_Score - 51%`, `User_Score - 40%` и `Rating - 40%`. Как можно заметить на визуализации зачастую это одни и те же наблюдения, т.е. как правило если нет данных в одном из этих столбцов, то данных нет и в 2-х других столбцах.

# %% [markdown]
# <a id='p2s1'></a>
# ## Подготовка даннаых
# ### Замена названия столбцов

# %%
games.columns = [col.lower().replace(' ','_') for col in games.columns] 
games.columns
# Out:
# Index(['name', 'platform', 'year_of_release', 'genre', 'na_sales', 'eu_sales',
#        'jp_sales', 'other_sales', 'critic_score', 'user_score', 'rating'],
#       dtype='object')

# %% [markdown]
# <a id='p2s2'></a>
# ### Преобразование типа данных

# %% [markdown]
# **`year_of_release`**

# %%
games.year_of_release.unique()
# Out:
# array([2006., 1985., 2008., 2009., 1996., 1989., 1984., 2005., 1999.,
#        2007., 2010., 2013., 2004., 1990., 1988., 2002., 2001., 2011.,
#        1998., 2015., 2012., 2014., 1992., 1997., 1993., 1994., 1982.,
#        2016., 2003., 1986., 2000.,   nan, 1995., 1991., 1981., 1987.,
#        1980., 1983.])

# %% [markdown]
# В столбце `year_of_release` данные хранятся в формате float, но при этом все значения этого столбца целочисленные. Т.к. такая точность тут не нужна, считаю верным преобразовать столбце в int.
#
# Т.к. в рассматриваемом столбце есть Nan, пока мы не избавимся от данных значений нам не удастся изменить тип данных. Таких значений всего 2%, поэтому считаю, что мы можем удалить строки с Nan.

# %%
games.dropna(subset=['year_of_release'], inplace=True)

# %%
data_loss()
# Out:
# 100.0

# %%
games.year_of_release = games.year_of_release.astype('int')
games.year_of_release.dtype
# Out:
# dtype('int32')

# %% [markdown]
# <a id='let_Nan_be'></a>
# **`critic_score`**
#
# Изначально данный столбец имеет тип `float64`, и если бы пропущенных данных было не так много, то мы могли бы изменить на тип `int64`. Оставляем тип без изменений.

# %%
games.critic_score.unique()
# Out:
# array([76., nan, 82., 80., 89., 58., 87., 91., 61., 97., 95., 77., 88.,
#        83., 94., 93., 85., 86., 98., 96., 90., 84., 73., 74., 78., 92.,
#        71., 72., 68., 62., 49., 67., 81., 66., 56., 79., 70., 59., 64.,
#        75., 60., 63., 69., 50., 25., 42., 44., 55., 48., 57., 29., 47.,
#        65., 54., 20., 53., 37., 38., 33., 52., 30., 32., 43., 45., 51.,
#        40., 46., 39., 34., 41., 36., 31., 27., 35., 26., 19., 28., 23.,
#        24., 21., 17., 13.])

# %%
games.critic_score.isna().sum() # слишком много Nan'ов. Оставляем
# Out:
# 8463

# %% [markdown]
# <a id='tbd'></a>
# **`user_score`**
#
# В данном столбце есть значение `tbd`, что является акронимом `to be determined` (будет определено). Значит на текущий момент мы не имеем информации о рейтинге с наблюдениями `tbd`. Заменяю их на Nan

# %%
games.query('user_score == "tbd"').shape[0] # посмотрим сколько нанов добавит данное действие
# Out:
# 2376

# %%
nan_count('user_score') # сколько было нанов до
# Out:
# 6607

# %%
games.loc[games['user_score'] == 'tbd', 'user_score'] = np.nan

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера  VERS#1 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
#
# Действительно tbd по смыслу не отличается от NaN

# %%
nan_count('user_score') # сколько стало нанов после
# Out:
# 8983

# %% [markdown]
# Теперь, когда в столбце `user_score` не осталось строковых значений мы можем изменить тип на `float64`

# %%
games.user_score = games.user_score.astype('float')
games.user_score.dtype
# Out:
# dtype('float64')

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера VERS#1 <a class="tocSkip"></h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
#  На данном шаге для колонки rating можно дополнительно посмотреть с какой частотой встречаются различные значения рейтинга. Возможно, редкие значения можно заменить на более распространенные. Или, если они составляют пренебрежимо малую долю в данных - их можно удалить.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента<a class="tocSkip"></h2>
#
# Проработал ниже
# </div>

# %%
games.rating.value_counts()
# Out:
# E       3921
# T       2905
# M       1536
# E10+    1393
# EC         8
# K-A        3
# AO         1
# RP         1
# Name: rating, dtype: int64

# %% [markdown]
# Рассмотрим каждый из редких рейтингов в отдельности:
# `«EC» («Early childhood»)` — Для детей младшего возраста: тут ничего не трогаем. Просто игр с таким рейтингом мало.
#
# `«K-A» («Kids to Adults»)` — «Для детей и взрослых»: Содержание игры вполне подходит для возрастной категории от 6 лет и старше. Такие игры подходят для всех возрастов. Они могут содержать минимальное насилие или немного грубый разговорный язык. Этот рейтинг был заменён на «Everyone» 1 января 1998 года и может встречаться только в играх, изданных ранее, кроме The Simpsons Cartoon Studio. Первой игрой, получившей данный рейтинг, стала SimCity 2000 в 1993 году.
#
# **Вывод:** можем заменить этот рейтинг рейтингом `E`
#
# `RP» («Rating Pending»“)` — «Рейтинг ожидается»: считаю возможным замену этого значения на Nan
#
# `AO» («Adults Only 18+»)` — «Только для взрослых»: Содержание игры только для взрослых. Продукты из данной категории могут содержать длительные сцены жестокого насилия и/или очень откровенное сексуальное содержимое, а также сцены с обнажением. В 2006-м году данный рейтинг получили 22 продукта, большинство из которых предназначены для персональных компьютеров под управлением Windows и Apple Macintosh. Рейтинг «Только для взрослых» является предметом многочисленных дискуссий, так как накладывает серьёзные ограничения на продажи игры.
#
# **Вывод:** весьма логично, что игр с таким рейтингом всего одна, ведь продвигать подобные игры будет весьма непросто. Да и будут ли они пользоваться популярностью у аудитории?

# %%
games.rating = games.rating.replace('K-A', 'E')
games.rating.value_counts()
# Out:
# E       3924
# T       2905
# M       1536
# E10+    1393
# EC         8
# AO         1
# RP         1
# Name: rating, dtype: int64

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера VERS#2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Супер проработка! Отдельный плюс за детальное изучение значений рейтингов👌

# %% [markdown]
# <a id='possible_nan_reasons'></a>
# ### Причины, которые могли привести к пропускам в столбцах с рейтингами.
# Могу предположить, что с ростом популярности и общедоступности сети интернет снизилось количество пропусков в данных: теперь и у обычных пользователей появился интернет и отзыв смог оставить каждый желающий. К тому же возможен рост и развитие игровой индустрии в целом, что подразумевает развитие площадок, на которых могут оставляться отзывы.

# %% [markdown]
# В столбце `year_of_release` данные хранятся в формате float, но при этом все значения этого столбца целочисленные. Т.к. такая точно

# %%
def null_ratio(df):
    return df.isna().sum() / df.shape[0]

# %%
nan_table = games.groupby('year_of_release').agg(null_ratio).reset_index()
nan_table = nan_table[['year_of_release', 'user_score']]
nan_table.columns = ['year_of_release', 'missing_data_ratio']
rcParams['figure.figsize'] = 20,10
nan_table.plot(x='year_of_release', y='missing_data_ratio', style='o-', grid=True)
plt.xticks(fontsize=14);

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера VERS#1 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Очень здорово, что рассмотрена динамика доли пропусков по годам.👍

# %% [markdown]
# <a id='sum_sale'></a>
# ### Подсчет суммарных продаж во всех регионах

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера VERS#1 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
#  Можно использовать следующую конструкцию для расчета суммы общих продаж:
#
#     df['total_sales']=df[['na_sales','eu_sales','jp_sales', 'other_sales']].sum(axis = 1)

# %%
games['sum_sales'] = games.na_sales + games.eu_sales + games.jp_sales + games.other_sales
games[['na_sales', 'eu_sales', 'jp_sales', 'sum_sales']].head(10)
# Out:
#    na_sales  eu_sales  jp_sales  sum_sales
# 0     41.36     28.96      3.77      82.54
# 1     29.08      3.58      6.81      40.24
# 2     15.68     12.76      3.79      35.52
# 3     15.61     10.93      3.28      32.77
# 4     11.27      8.89     10.22      31.38
# 5     23.20      2.26      4.22      30.26
# 6     11.28      9.14      6.50      29.80
# 7     13.96      9.18      2.93      28.91
# 8     14.44      6.94      4.70      28.32
# 9     26.93      0.63      0.28      28.31

# %% [markdown]
# **Вывод:** на этапе подготовки данных объяснили причину возниконовения отсутствующих значений. Также провели замену рейтингов `K-A` на `E`. Произвели замену значений tbd на NaN, т.к. по смыслу это одно и тоже, а дополнять график еще одной колонкой нежелательно

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера VERS#1 <a class="tocSkip"></h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# 1. Не хватает вывода по результатам выполненной работы.
# 2. Хочу посоветовать тебе статью, которая рассматривает разные способы обработки пропусков, в том числе их удаление/игнорирование, выделяет их плюсы и минусы, думаю, тебе может быть интересно: https://loginom.ru/blog/missing

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента<a class="tocSkip"></h2>
#
# Дополнил вывод, со статьей ознакомлюсь🙃
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера VERS#2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# +

# %% [markdown]
# <a id='p3s1'></a>
# ## Исследовательский анализ
# ### Сколько игр выпускалось в разные годы

# %%
game_release_count = games.groupby('year_of_release')['name'].count()
game_release_count = game_release_count.to_frame().reset_index()

# fig = px.bar(game_release_count, x='year_of_release', y='name')
# fig.update_xaxes(nticks=20)
# fig.update_layout(title_text="Количество вышедших игр в год", title_x=0.5,title_y=0.94)
# fig.update_xaxes(title_text="Год релиза")
# fig.update_yaxes(title_text="Количество игр")
# fig.show()

# %%
sns.set_theme(style='darkgrid')
sns.set(font_scale=1.3)
g = sns.displot(data=games, x='year_of_release', edgecolor='.3', bins=games.year_of_release.nunique())
g.figure.set_size_inches(16, 8)
g.set(xlabel='Год релиза', ylabel='Количество игр', title='Количество вышедших игр в год')

# %% [markdown]
# В некоторые годы, когда гейм девелоп еще только зарождался игр было совсем мало (зато какие 😪). Годы с малым количеством наблюдений могут иметь много шумов, к тому же с тех времен многое изменилось и рекламные компании, которые могли бы сработать тогда, возможно, не сработают сейчас. Например, платформамы все время сменяются более производительными и современными. Следовательно следует рассматривать не такие давние времена с большим количеством наблюдений.

# %% [markdown]
# <a id='p3s2'></a>
# ### Изменение продаж по платформам
# #### Выведем топовые по прадажам игр платформы

# %%
top_platforms = games.groupby('platform')['sum_sales'].sum().sort_values(ascending=False).head(8)
top_platforms
# Out:
# platform
# PS2     1233.56
# X360     961.24
# PS3      931.34
# Wii      891.18
# DS       802.78
# PS       727.58
# PS4      314.14
# GBA      312.88
# Name: sum_sales, dtype: float64

# %% [markdown]
# #### Выведем данные по продажам игр по каждой платформе за каждый год.

# %%
top_sale_platforms = games.query('platform in @top_platforms.index and year_of_release > 1995')
sales = top_sale_platforms.pivot_table(index=['year_of_release', 'platform'], values='sum_sales', aggfunc='sum').reset_index()
sales.platform
# Out:
# 0       PS
# 1       PS
# 2       PS
# 3       PS
# 4      GBA
#       ...
# 71    X360
# 72     PS3
# 73     PS4
# 74     Wii
# 75    X360
# Name: platform, Length: 76, dtype: object

# %%
fig = px.bar(sales, x='year_of_release', y='sum_sales', color='platform', title='Продажи игр по платформам с 1996 по 2016 год', \
             labels={'sum_sales': 'Продажи', 'year_of_release':'Год'}, \
             barmode='group')
rcParams['figure.figsize'] = 20,10
#fig.show()
response = requests.get('https://sun9-west.userapi.com/sun9-14/s/v1/ig2/b04SKmYfuY6i5CGI--Ce1LeJcnrNH4Q_THQpL3uDYeZ4jvVOFMj-QpIzgsfRybPPwe0E8VzEgy0NzCNMN9_EciEz.jpg?size=983x525&quality=96&type=album')
Image.open(BytesIO(response.content))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=983x525 at 0x276404FA5E0>

# %% [markdown]
# На примере PlayStation можно наблюдать, как платформа появляется, достигает пика продаж игр и потом затухает. Периоды появления и затухания продаж накладываются друг на друга. Этот цикл занимает примерно 5 лет. Объяснить это можно устареванием платформы: платформа уже не отвечает системным требованиям современных игр и приходится выпускать более новую и производительную игровую приставку. Если оставить на графике только платформы от PlayStation можно заметить, что игры PS3 уже не достигли такого пика продаж, как в период, напирмер, с 2000 по 2006 год. Это можно связать с тем, что PS3 в годы пришлось конкурировать и делить рынок с другими игровыми платформами. Например с xBox360: продажи игр по PS3 и xBox360 были примерно одинаковы в каждый год.
# Также можно заметить что заметный рост продаж в целом совпадает с ростом продаж по PS. стартом роста продаж можно обозначить 1994 год.

# %% [markdown]
# <a id='p3s3'></a>
# ### Актуальный период.
# Т.к. средний цикл "зарождения" и "смерти" платформы я определил в 5 лет, а прогноз нужно строить для 2017 года, то актуальным периодом будет период с 2011 по 2016. И на этот раз не будем ограничиваться только 8-ю платформами. Т.к. временной промежуток мы заметно сократим, пространства на графике будет достаточно для отображения большего количества платформ.

# %%
recent_platforms = games.query('year_of_release > 2011')
platforms_to_invest = recent_platforms.pivot_table(index=['year_of_release', 'platform'], \
                                                   values='sum_sales', \
                                                   aggfunc='sum').reset_index()

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера VERS#1<a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# Действительно, для анализа нужно выбрать последние годы и посмотреть какие из платформ продаются на текущий момент, чтобы строить какие-то прогнозы на 2017 год. Поэтому следует отбросить старые ожившие тренды и не учитывать пиковые значения прошлых лет, так как эти данные в большей части соответсвуют платформам, не работающим к текущему моменту, а также могут значительно исказить оценку новых зарождающих трендов. За актуальный лучше выделять период ***не ранее с 2012 года***, что будет соответствовать ориентировочно году начала работы действующих платформ, чей пик приходится на последние года (2014-2015). Хотелось бы отметить, что в традиционных бизнесах редко берут данные более чем за 2-3 года. А в такой динамично меняющейся индустрии, как компьютерные игры и вовсе не стоит брать слишком большой временной интервал - иначе обязательно захватишь уже отжившие тренды. Но и слишком короткий период тоже не стоит брать.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента<a class="tocSkip"></h2>
#
# Скорректировал актуальный период. Исключил 2011 и 2016 годы.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера VERS#2<a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
#
# Согласна с актуальным периодом с 2012 года, но в коде выше исключаются значения меньше 2016 года и поэтому наш набор данных становится пустым( Перепутан знак 😌
#     Дополнительно замечу, что обычно прогноз на будущий год составляется в октябре, когда текущий год еще не закрыт. При этом данные текущего года не удаляют, т.к. они содержат самую свежую информацию - пусть и не полную. Поэтому лучше оставить 2016 год в датасете для последующего анализа.
#
# Забегу вперед: это единственное критическое замечание - осталось его поправить и проект будет завершен.
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента VERS#2<a class="tocSkip"></h2>
#
# Да, глупая ошибка) Теперь период с 2012 года.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера VERS#3 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Теперь актуальный период выделен корректно 🤗

# %% [markdown]
# <a id='p3s4'></a>
# ### Лидируют по продажам

# %%
fig = px.bar(platforms_to_invest, x='year_of_release', y='sum_sales', color='platform', \
             title='Продажи игр по платформам с 2011 года', \
             labels={'sum_sales': 'Продажи', 'year_of_release':'Год'}, \
             barmode='group')
rcParams['figure.figsize'] = 20,10
#fig.show()
response = requests.get('https://sun9-north.userapi.com/sun9-77/s/v1/ig2/VNWUMrqghip3snKLVXBy-WJhFnPLyvVPx_RVQ_zwxuogDd69TLhN5BQULFpKRvNbUEbirADAazjpZdT3b-GT1C_0.jpg?size=983x525&quality=95&type=album')
Image.open(BytesIO(response.content))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=983x525 at 0x276419A4670>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера VERS#2<a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
#
# Код падает с ошибкой по причине отсутствия данных в датасете. После изменения решения по выделению актуального периода код в ячейке выше должен отрабатывать без ошибок.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера VERS#3 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
# +

# %% [markdown]
# <a id='p3s4'></a>
# Платформы DS, PC, PS3, PSP и Х360 имеют нисходящий тренд, следовательно их потенциальная прибыльность низка. 3DS находится в середине своего жизненного цикла и падения продаж пока не наблюдается. Кроме того из вышеперечисленных платформ какими-то значительными продажами обладают только 3DS, PS3 и Х360. Логично, что эти платформы хотят сохранить свое присутствие на рынке и производят новое поколение своих платформ: Х360 и ХOne, PS3 и PS4. Если просмотреть эти пары платформ отключив отображение остальных в легенде, то можно отчетливо видеть, как старое поколение снижает продажи игр на своей платформе, а новое набирает.
# Отдельного внимания заслуживает PC: понятие смены поколений не применимо к персональному комьютеру.
# #### Вывод: наиболее перспективные платформы: PS4 и XOne. Также можно рассмотреть WiiU, т.к. данная платформа пришла на замену Wii, но имеет значительно меньшие объемы продаж в сравнении с вышеупомянутыми и не имеет ярко выраженного восходящего тренда.

# %% [markdown]
# <a id='p3s5'></a>
# ### Ящик с усами

# %%
fig = px.box(recent_platforms, x="platform", y="sum_sales", hover_data=['name','sum_sales', 'year_of_release', 'genre'], height=800)
fig.update_layout(title_text="Ящик с усами продаж по платформам за актуальный период")
fig.update_xaxes(title_text="Платформа")
fig.update_yaxes(title_text="Продажи")
#fig.show()
response = requests.get('https://sun9-east.userapi.com/sun9-33/s/v1/ig2/XTKlwrZK-CvfORfzpuGhrRiHGgRC7tdwmef8B7VsB5ocCUKk9DYAbgk2cax-Ea5yJIkgGw1LgCbR631c2iOHoM0-.jpg?size=983x800&quality=95&type=album')
Image.open(BytesIO(response.content))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=983x800 at 0x2763D8107C0>

# %%
fig = px.box(recent_platforms, x="platform", y="sum_sales", hover_data=['name','sum_sales', 'year_of_release', 'genre'], height=600)
fig.update_layout(title_text="Ящик с усами продаж по платформам за актуальный период")
fig.update_xaxes(title_text="Платформа")
fig.update_yaxes(title_text="Продажи")
fig.update(layout_yaxis_range = [0,2])
#fig.show()
response = requests.get('https://sun9-east.userapi.com/sun9-27/s/v1/ig2/mHnIr0nD9rIYzIwNlnNRdYzUTagYF8YZOl_sVHSAr7wvr9pRnbWoSLUB4xWtIg669jhdBaZrh7olmuayM02yAXuQ.jpg?size=983x600&quality=95&type=album')
Image.open(BytesIO(response.content))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=983x600 at 0x2763DB453D0>

# %% [markdown]
# На каждой платформе есть удачные игры, продажи которых намного выше других. Эти удачные игры видимо ввиду их популярности можно увидеть на нескольььких платформах (например GTA V). На этих аномалиях зарабатывается очень много денег, но в целом показатели продаж всех платформ находятся на одном уровне.
#
# На графике с другим масштабом можно лучше посмотреть на медианные значения и межквартильный размах по каждой платформе.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера VERS#1<a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
#
# К сожалению, на полученном графике плохо различимы медианы, и для более обоснованных выводов следует сделать дополнительный график, где будет отображена только нижняя часть boxplot-ов. Этого можно добиться, например, задав параметр ylim или figsize.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента<a class="tocSkip"></h2>
#
# Построил еще один график с другим масштабом и дополнил промежуточный вывод
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера VERS#2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# +

# %% [markdown]
# <a id='p3s6'></a>
# ### Влияние отзывов на продажи
# В качестве популярной платформы я выберу `PS3`, т.к. цикл жизни этой платформы уже имеет ярко выраженный нисходящий тренд и за этот период игры этой платфорсы уже собрали большое количество отзывов (самая популярная игра в период с 2011 года была выпущена именно на этой платформе).

# %%
def critic_sell_corr(df):    
    rcParams['figure.figsize'] = 10,6
    df.plot.scatter(x='sum_sales', y='critic_score')
    df.plot.scatter(x='sum_sales', y='user_score')
    df.plot.scatter(x='critic_score', y='user_score')
    
    correlation_matrix = df[['sum_sales', 'user_score', 'critic_score']].corr()

    plt.figure(figsize=(2,3))
    sns.heatmap(correlation_matrix[['sum_sales', 'critic_score']].sort_values(by='sum_sales', ascending=False), \
                cmap='seismic', annot=True)

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера VERS#1<a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# 1. Ниже ты берешь период с 2006 года, но здесь стоит выполнить анализ на данных за актуальный период. Пояснение: конечная цель анализа заключается в выявление определяющих успешность игры закономерностей, для того чтобы сделать ставку на потенциально популярный продукт и спланировать рекламные кампании. То есть для определения будущих перспектив будет корректнее использовать данные за актуальный период.
#
# 2. Выше наиболее перспективными платформами были определены PS4 и XOne, поэтому было бы здорово в первую очередь провести анализ на текущем шаге для одной из них.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента<a class="tocSkip"></h2>
#
# С годом я действительно ошибся. Платформу изменил на PS4. Коэффициенты корреляции изменились ввиду внесенных изменений, поэтому промежуточный вывод тоже поправил
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера VERS#2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Согласан с анализом PS4 как наиболее перспективной консоли. Единственное уточнение -анализ ниже можно сразу сделать на датасете выделенном в актуальном периоде - recent_platforms и тогда не придется делать дополнительную фильтрация по годам.

# %%
top_platform = games.query('platform == "PS4" and year_of_release in [2012, 2013, 2014, 2015]')
critic_sell_corr(top_platform)
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %% [markdown]
# **Оценки критиков** имеют `слабую` положиьельную корреляцию с продажами. В свою очередь **оценки пользователей** с продажами `очень слабую`. При этом можно видеть `среднюю` корреляцию оценок пользователей и критиков.
#
# **Вывод: оценки критиков более экспертны**

# %% [markdown]
# <a id='p3s7'></a>
# ### Продажи на других платформах

# %%
# platforms_list = ['PS3', 'X360', 'XOne', 'WiiU', 'Wii']
# other_platforms = games.query('platform in @platforms_list and year_of_release >= 2011')
# fig = px.scatter_matrix(other_platforms,
#     dimensions=["critic_score", "user_score", "sum_sales"],
#     title="Продажи игр в зависимости от оценок критиков и игроков",
#     color="platform", 
#     opacity=0.8,
#     labels={'critic_score': 'Оценка критиков', 'user_score': 'Оценка игроков', 'sum_sales': 'Продажи'}, height=1000, width=1000)
# fig.show()

# %%
import plotly.express as px
platforms_list = ['PS3', 'X360', 'XOne', 'WiiU', 'Wii']
other_platforms = games.query('platform in @platforms_list and year_of_release >= 2011')
fig = px.scatter_matrix(other_platforms,
    dimensions=["critic_score", "user_score", "sum_sales"], color='platform', title="Продажи игр в зависимости от оценок критиков и игроков", opacity=0.8,labels={'critic_score': 'Оценка критиков', 'user_score': 'Оценка игроков', 'sum_sales': 'Продажи'}, height=1000, width=1000)
fig.update_traces(diagonal_visible=False, showlowerhalf=False)
#fig.show()
response = requests.get('https://sun9-west.userapi.com/sun9-71/s/v1/ig2/UrLvfzksqhkihG9daFsS_9NvBvi7sWc0j4SR80kEtM2fsTIPLQlEHaGeYszQ_gJo8nL39ASmasnelYljX8NKh8Ng.jpg?size=1000x1000&quality=95&type=album')
Image.open(BytesIO(response.content))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1000x1000 at 0x2763DDB5970>

# %% [markdown]
# На первый взгляд график (матрица) из-за нагромождения платформ может показаться нечитаемым, но можно отключать отображение платформ на графике в легенде и просмотреть каждую платформу в отдельности.
#
# Чтобы не писать код для корреляции по каждой платформе напишем функцию и выведем все платформы сразу

# %%
top_platforms = ['PS3', 'X360', 'XOne', 'WiiU', 'Wii', 'DS']

rows = len(top_platforms) // 2
cols = 2
fig, axes = plt.subplots(rows, cols, figsize=(15,8.5))
count = 0
for r in range(rows):
    for c in range(cols):
        curr_platform = top_platforms[count]
        df_prep = games[(games['platform'] == curr_platform) & (games['user_score'] > 0)].copy()
        
        df_filtered = df_prep[['sum_sales' ,'critic_score', 'user_score']]
        sns.set(font_scale=1.0)
        ax = sns.heatmap(df_filtered.corr()[['sum_sales']].sort_values(by='sum_sales', ascending=False), 
                         cmap="seismic", annot=True, ax=axes[r,c])
        ax.set_title(curr_platform, fontsize=20)
        ax.set_yticklabels(ax.get_yticklabels(), rotation=0)
        plt.tight_layout(pad=3)
        count += 1

# %%
# def corr_platform(plat):
#     correlation_matrix = other_platforms.query('platform == @plat')[['sum_sales', 'user_score', 'critic_score']].corr()
#     plt.figure(figsize=(1,2.5))
#     sns.heatmap(correlation_matrix[['sum_sales']].sort_values(by='sum_sales', ascending=False), \
#                 cmap='seismic', annot=True)
#     plt.title(plat, fontsize = 16)

# corr_platform('PS3'), corr_platform('X360'), corr_platform('XOne'), corr_platform('WiiU'), corr_platform('Wii')

# %% [markdown]
# Корреляция по суммам продажи на других платформах схожа с корреляцией на `PS4`

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера VERS#1<a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
# 1.  Для удобства приведу текст задания по данному разделу:
#
#         Посмотрите, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Постройте диаграмму рассеяния и посчитайте корреляцию между отзывами и продажами. Сформулируйте выводы.
#         Соотнесите выводы с продажами игр на других платформах.
#
# То есть необходимо взять в анализ несколько (4-6 шт) актуальных платформ и ***отдельно для каждой*** рассчитать коэффициенты корреляции и построить диаграммы рассеяния, так как выводы, сделанные на основе расчетов по нескольким платформам выглядят весомей и убедительней. Пожалуйста скорректируй данный раздел проекта и в анализе используй данные ***за актуальный период.***
#
# 2. При интерпретации значений корреляции можно использовать следующую градацию:
#
#         0 до 0,3 очень слабая
#         от 0,3 до 0,5 слабая
#         от 0,5 до 0,7 средняя
#         от 0,7 до 0,9 высокая
#         от 0,9 до 1 очень высокая
#
# Например, корреляция 0.392 говорит о слабой связи, или значение корреляции на уровне 0.13 считается очень слабой и такую корреляцию в большинстве случаев не стоит принимать в расчет. На всякий случай напомню, что корреляцию оценивают по модулю значения.
#
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента<a class="tocSkip"></h2>
#
# Построил матрицу для нескольких платформ. На первый взгляд матрица не читаема по отдельным платформам, но в легенде можно отключить отоюражение платформ и проспотреть каждую в отдельности. В противном случае пришлось бы строить график для каждой из 5 платформ в отдельности, что заняло бы намного больше места. Также построил хитмепы с коэфициентами корреляции по каждой платформе.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера VERS#2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Плюсую за использование plotly👏

# %% [markdown]
# **Вывод: при более высоких оценках критиков наблюдается тенденция на более высокий разброс по продажам, т.е. чем больше оценка критиков, тем больше продаж.**

# %% [markdown]
# <a id='p3s8'></a>
# ### Общее распределение игр по жанрам

# %% [markdown]
# Посмотрим на распределение продаж по жанрам игр. Посмотрим сумму и медиану по продажам, ведь, как мы заметили ранее, в данных есть выбросы в виде игр, которые достигли выдающегося успеха в плане продаж на многих платформах.

# %%
def gen_dis(aggr):
    genres_distr = recent_platforms.pivot_table(index='genre', values='sum_sales', aggfunc=aggr).reset_index()
    genres_distr.columns = ['genre', 'total_genre_sales']
    genres_distr.sort_values(by='total_genre_sales', ascending=False, inplace=True)
    fig = px.bar(genres_distr, x='genre', y='total_genre_sales', height=600)
    fig.update_xaxes(title_text="Жанр")
    fig.update_yaxes(title_text="Продажи")
    fig.show()

# display(gen_dis('sum'), gen_dis('median'))
response = requests.get('https://sun9-north.userapi.com/sun9-84/s/v1/ig2/y3zp16-nueId8y0hn2G-aMTLH6k0d1WhpwpFSMaLxWoNgTBU8IKdW1RvrBD8ZgOXP0W_0v4hVJACUQPK0N5DCy8Q.jpg?size=983x600&quality=95&type=album')
Image.open(BytesIO(response.content))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=983x600 at 0x2763DB31E20>

# %%
response = requests.get('https://sun9-east.userapi.com/sun9-23/s/v1/ig2/GvkwhKjqFIFN-oo5MQlHkxk_8PDyEo5k3ysxCuA57pYuaGRMw5KvygMgcBzwwBSGDIhnDx3EcYIWYSoT1Js_iT1x.jpg?size=983x600&quality=95&type=album')
Image.open(BytesIO(response.content))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=983x600 at 0x276365ECFD0>

# %% [markdown]
# Диаграммы размаха, построенные по жанрам дадут нам большее представление о продажах по каждому жанру

# %%
fig = px.box(recent_platforms, x="genre", y="sum_sales", hover_data=['name','sum_sales', 'year_of_release', 'genre', 'platform'], height=600)
fig.update_layout(title_text="Ящик с усами продаж по жанрам за актуальный период")
fig.update_xaxes(title_text="Жанр")
fig.update_yaxes(title_text="Продажи")
# fig.show()
response = requests.get('https://sun9-west.userapi.com/sun9-53/s/v1/ig2/kMEp16BYZiZMXAWDkjhyfQyyqeZ5R_eJ6A_WpJxnZV_rcUYSgZ6zcifTBfsc4NFy_b5Dn2x5tr0vo3kI3Lr2tl58.jpg?size=983x600&quality=95&type=album')
Image.open(BytesIO(response.content))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=983x600 at 0x27636605DC0>

# %%
fig = px.box(recent_platforms, x="genre", y="sum_sales", hover_data=['name','sum_sales', 'year_of_release', 'genre'], height=600)
fig.update_layout(title_text="Ящик с усами продаж по платформам за актуальный период")
fig.update_xaxes(title_text="Платформа")
fig.update_yaxes(title_text="Продажи")
fig.update(layout_yaxis_range = [0,4])
# fig.show()
response = requests.get('https://sun9-west.userapi.com/sun9-13/s/v1/ig2/4h4yshNy-Du2NupsqANfSgvbnOI7BNif6mhrLSMdzZ_a3iQt06DT13-G4G6J1GXiVA8gOgyR35nEUO8Q481VPbVb.jpg?size=983x600&quality=95&type=album')
Image.open(BytesIO(response.content))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=983x600 at 0x2763DD5FB80>

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера VERS#1<a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b>
#
# На последнем графике явно заметно отличие  Shooter от остальных жанров, но здесь также было бы здорово отобразить, только нижнюю часть графика.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента<a class="tocSkip"></h2>
#
# Дополнил еще одним графиком с другим масштабом
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера VERS#2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# +

# %% [markdown]
# Как и предполагалось. По медиане и сумме продаж по жанрам результаты разнятся:
# `В сумме` по продажам самым популярным жанром оказался жанр `Action, Shooter и Role-Playing` – тут большой вклад в `Action` видимо сделала GTA V, ведь только по этой игре на платформе PS3 был 21 миллион продаж (+ на X360 еще 16 млн.). А жанр `Puzzle` по суммам продаж оказался наименее популярным.
#
# `С медианными` значениями дела обстоят немного иначе: `Action` уже не занимает первое место по продажам и даже не входит в тройку самых продавающих жанров. Теперь первенство возглавляют `Shooter, Sports и Platform`, а на последнем месте уже `Adventure`.
#
# **Вывод: самыми перспективными жанрами `в рассматриваемый период` являются `Shooter, Sports и Platform`.**
#
# Стоит учитывать, что с течением времени популярность жанров изменяется, и если мы будем рассматривать другой временной период, то популярность жанров может быть уже другой. Например в период с 1985 по 1995 года, в эру поплуряности так называемых `денди`, жанр платформеры был намного популярнее, чем в текущий период и занимал лидирующие позиции и по медиане и по сумме продаж.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера VERS#1 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Согласна с логикой анализа на данном шаге. Отмечу, что общие продажи - плохая метрика для поиска наиболее прибыльного жанра. За высокими показателями общих продаж может скрываться множество мелких игр с низкими продажами. Или 2-3 звезды и куча провалов. Лучше найти жанр, где игры стабильно приносят высокий доход - для этого,действительно, стоит рассмотреть средние или медианные продажи.

# %% [markdown]
# <a id='p4s1'></a>
# ## Портрет пользователя каждого региона
# ### Самые популярные платформы

# %% [markdown]
# Для начала найдем самые популярные платформы для каждого региона в отдельности

# %%
top_na_platforms = recent_platforms.pivot_table(index='platform', values='na_sales', aggfunc='sum').reset_index().sort_values(by='na_sales', ascending=False).head()
top_eu_platforms = recent_platforms.pivot_table(index='platform', values='eu_sales', aggfunc='sum').reset_index().sort_values(by='eu_sales', ascending=False).head()
top_jp_platforms = recent_platforms.pivot_table(index='platform', values='jp_sales', aggfunc='sum').reset_index().sort_values(by='jp_sales', ascending=False).head()
display(top_na_platforms, top_eu_platforms, top_jp_platforms)
# Out:
#    platform  na_sales
# 9      X360    140.05
# 4       PS4    108.74
# 3       PS3    103.38
# 10     XOne     93.12
# 0       3DS     55.31
#    platform  eu_sales
# 4       PS4    141.09
# 3       PS3    106.86
# 9      X360     74.52
# 10     XOne     51.59
# 0       3DS     42.64
#   platform  jp_sales
# 0      3DS     87.79
# 3      PS3     35.29
# 6      PSV     21.04
# 4      PS4     15.96
# 8     WiiU     13.01

# %% [markdown]
# Затем объединим эти таблицы по платформам. Делаем мы это для того, чтобы в нашем топе отобразить все платформы, которые входили в топ 5 каждой страны.

# %%
top_region_platforms = top_na_platforms.merge(top_eu_platforms, on='platform', how='outer')
top_region_platforms = top_region_platforms.merge(top_jp_platforms, on='platform', how='outer')
top_region_platforms
# Out:
#   platform  na_sales  eu_sales  jp_sales
# 0     X360    140.05     74.52       NaN
# 1      PS4    108.74    141.09     15.96
# 2      PS3    103.38    106.86     35.29
# 3     XOne     93.12     51.59       NaN
# 4      3DS     55.31     42.64     87.79
# 5      PSV       NaN       NaN     21.04
# 6     WiiU       NaN       NaN     13.01

# %%
fig = px.bar(top_region_platforms, x='platform', y=['na_sales', 'eu_sales', 'jp_sales'], \
             title='Продажи по платформам', barmode='group', \
            labels={'value':'Продажи', 'platform':'Платформы', 'variable': 'Страны'})

fig.update_layout(
    legend=dict(
        x=0.87,
        y=1,
        title_font_family="Times New Roman",
        font=dict(
            size=12,
            color="black"
        ),
        bordercolor="Black",
        borderwidth=1
    )
)
newnames = {'na_sales':'Америка', 'eu_sales': 'Европа', 'jp_sales':'Япония'}
fig.for_each_trace(lambda t: t.update(name = newnames[t.name]))

# fig.show()
response = requests.get('https://sun9-east.userapi.com/sun9-44/s/v1/ig2/WjtrK0GqFA2kwbxIjXdYxkTDohNvcb-wwvH7iHoQSYJIrl5IGF4nFgG3Wl_P-jVRHpiJyOBQ6s3AF4MCXxbxxbEs.jpg?size=983x525&quality=95&type=album')
Image.open(BytesIO(response.content))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=983x525 at 0x276419A4850>

# %% [markdown]
# В некоторых регионах продажи игр по некоторым платформам вообще отсутствуют: игры `Х360` отсутствуют в `Японии (jp_sales)`. Продажи по `XOne` есть только в `Северной Америке (na_sales)` и `Европейском союзе (eu_sales)`. Продажи по `PSP` и `WiiU` характерны только для `Японии (jp_sales)`. Единственные платформы, которые имеют продажи по всем регионам это `PS3`, `PS4` и `3DS`. В целом продажи по всем платформам в `Японии` низки в сравнении с другими регионами

# %% [markdown]
# <a id='p4s2'></a>
# ### Самые популярные жанры
# Проделаем те же шаги для определения топов популярных жанров по регионам

# %%
top_na_genres = recent_platforms.pivot_table(index='genre', values='na_sales', aggfunc='sum').reset_index().sort_values(by='na_sales', ascending=False).head()
top_eu_genres = recent_platforms.pivot_table(index='genre', values='eu_sales', aggfunc='sum').reset_index().sort_values(by='eu_sales', ascending=False).head()
top_jp_genres = recent_platforms.pivot_table(index='genre', values='jp_sales', aggfunc='sum').reset_index().sort_values(by='jp_sales', ascending=False).head()
display(top_na_genres, top_eu_genres, top_jp_genres)
# Out:
#            genre  na_sales
# 0         Action    177.84
# 8        Shooter    144.77
# 10        Sports     81.53
# 7   Role-Playing     64.00
# 3           Misc     38.19
#            genre  eu_sales
# 0         Action    159.34
# 8        Shooter    113.47
# 10        Sports     69.09
# 7   Role-Playing     48.53
# 6         Racing     27.29
#           genre  jp_sales
# 7  Role-Playing     65.44
# 0        Action     52.80
# 3          Misc     12.86
# 9    Simulation     10.41
# 2      Fighting      9.44

# %%
top_region_genres = top_na_genres.merge(top_eu_genres, on='genre', how='outer')
top_region_genres = top_region_genres.merge(top_jp_genres, on='genre', how='outer')
top_region_genres
# Out:
#           genre  na_sales  eu_sales  jp_sales
# 0        Action    177.84    159.34     52.80
# 1       Shooter    144.77    113.47       NaN
# 2        Sports     81.53     69.09       NaN
# 3  Role-Playing     64.00     48.53     65.44
# 4          Misc     38.19       NaN     12.86
# 5        Racing       NaN     27.29       NaN
# 6    Simulation       NaN       NaN     10.41
# 7      Fighting       NaN       NaN      9.44

# %%
fig = px.bar(top_region_genres, x='genre', y=['na_sales', 'eu_sales', 'jp_sales'], \
             title='Продажи по жанрам', barmode='group', \
             labels={'value':'Продажи', 'genre':'Жанры', 'variable': 'Страны'})

fig.update_layout(
    legend=dict(
        x=0.87,
        y=1,
        title_font_family="Times New Roman",
        font=dict(
            size=12,
            color="black"
        ),
        bordercolor="Black",
        borderwidth=1
    )
)
newnames = {'na_sales':'Америка', 'eu_sales': 'Европа', 'jp_sales':'Япония'}
fig.for_each_trace(lambda t: t.update(name = newnames[t.name]))

# fig.show()
response = requests.get('https://sun9-east.userapi.com/sun9-36/s/v1/ig2/jfxljIBxBZ-JHtA357io4qFCojrxrzYEP4LcPQkZc_D968OFa-S8cgVBmeByhVC4erqZRix7pzsnG0KT8yvcVtde.jpg?size=983x525&quality=95&type=album')
Image.open(BytesIO(response.content))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=983x525 at 0x276415B4D90>

# %% [markdown]
# В `Японии (jp_sales)` показатели продаж за рассматриваемый период в жанрах `shooter` и `sports` отсутствуют. По `action` продажи выше всего и игры этого жанра продаются во всех регионах. Так же продажи `role-playing` игр присутствует во всех регионах, но продажи игр этого жанра существенно ниже и сравнимы по всем регионам. Продажи `simulation` и `platform` игр есть только в `Японии`

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера VERS#1<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
#
# Руслан, отличная работа! В целом Европа и Северная Америка очень похожи между собой по предпочтениям платформ и жанров, в то время как Япония более самобытна👏.

# %% [markdown]
# <a id='p4s3'></a>
# ### Влияние рейтинга ESRB на продажи в отдельном регионе

# %% [markdown]
# Посмотрим на уникальные значения столбца и узнаем что и какой рейтинг значит.
# http://www.gamer.ru/everything/reytingi-esrb-ot-a-do-ya?ysclid=l9xa2nastr102556381

# %% [markdown]
# Рейтинг `RP` означает rating pending – продукт был отправлен в ESRB и ожидает присвоение рейтинга. То есть рейтинг еще не присвоен. При выводе результатов и формулировании вывода стоит это учесть

# %%
recent_platforms['rating'] = recent_platforms['rating'].replace('RP', np.nan)
recent_platforms['rating'] = recent_platforms['rating'].replace(np.nan, 'not specified')

# %%
na_rating = recent_platforms.pivot_table(index='rating', values='na_sales', aggfunc='sum').reset_index().sort_values(by='na_sales', ascending=False)
eu_rating = recent_platforms.pivot_table(index='rating', values='eu_sales', aggfunc='sum').reset_index().sort_values(by='eu_sales', ascending=False)
jp_rating = recent_platforms.pivot_table(index='rating', values='jp_sales', aggfunc='sum').reset_index().sort_values(by='jp_sales', ascending=False)
region_rating = na_rating.merge(eu_rating, on='rating', how='outer')
region_rating = region_rating.merge(jp_rating, on='rating', how='outer')
fig = px.bar(region_rating, x='rating', y=['na_sales', 'eu_sales', 'jp_sales'], \
             title='Продажи по возрастным рейтингам', barmode='group', \
             labels={'value':'Продажи', 'rating':'Рейтинги', 'variable': 'Страны'})

fig.update_layout(
    legend=dict(
        x=0.87,
        y=1,
        title_font_family="Times New Roman",
        font=dict(
            size=12,
            color="black"
        ),
        bordercolor="Black",
        borderwidth=1
    )
)
newnames = {'na_sales':'Америка', 'eu_sales': 'Европа', 'jp_sales':'Япония'}
fig.for_each_trace(lambda t: t.update(name = newnames[t.name]))

# fig.show()
response = requests.get('https://sun9-west.userapi.com/sun9-39/s/v1/ig2/cwp9MJRrBR1wzuTtYaClPT47o4LNINZNlpOUF4Iq6RmBPGTtimGRaiaaISyTVWmMYO_osbaFq1LwVp8x86yUkPW5.jpg?size=983x525&quality=95&type=album')
Image.open(BytesIO(response.content))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=983x525 at 0x2763D25BB80>

# %% [markdown]
# В `Европе` и `Америке` в основном продаются игры рейтинга `M («Mature»)`. Скорее всего это связано с высокими продажами жанров `action` и `shooter`. В этих жанрах обычно стоит жесткий возрастной ценз. В Японии самые высокие показатели возрастных групп `E («Everyone»)` и `T («Teen»)`, что тоже объясняется популярностью жанров `ролевых игр`, `файтингов` и `платформеров`, на которые нет жестких ограничений по возрасту. Так же в Японии популярны игры, рейтинг которых не указан. Продажи по этой возрастной категории превышает суммарные продажи по всем остальным возрастным категориям `в Японии`. Продажи в остальных регионах по этой неизвестной возрастной кагероии примерно на одном уровне. Интересно, что это за категория?

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера VERS#1<a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
#
# В твоем анализе игры без рейтинга(пустые значения) оказываются полностью исключенными. Но продажи именно этих игр могут указать на ключевое различие в регионах.Их следует учесть и пересмотреть выводы согласно полученным результатам. Пожалуйста укажи в выводах есть ли совпадения/различия в регионах по влиянию рейтинга ESRB
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента<a class="tocSkip"></h2>
#
# В таком случае можно заменить nan на "not specified", и этот рейтинг будет отображаться в нашем графике.
#
# Скорректировал промежуточный вывод, добавив туда информацию по продажам по неуказанной возрастной категории в Японии. Так же скорректировал конечный вывод
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера VERS#2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Относительно Японии замечу, что там действует своя локальная организация CERO по рейтингам. Возможно, игры без рейтинга  ESRB в других регионах, это игры, которые были созданы в Японии и в Европе - но это предположение, и его следует проверить.

# %% [markdown]
# <a id='p5s1'></a>
# ## Проверка гипотез

# %% [markdown]
# <a id='p5s4'></a>
# Для проверки гипотез будем использовать критерий двусторонней гипотезы и t-test'ом для 2х независимых выборок. Этот тетст для нулевой гепотезы о равенстве средних 2х выборок. В этом тесте есть параметр equal_var, который по дефолту = True, что значит что дисперсия наших данных в 2х выборках равна. Нужно это проверить и если вариативность данных в выборках не равна, то изменить значение этого параметра на False.
#
# Сформируем 2 выборки и посмотрим на их дисперсии.

# %%
XOne_userscore = recent_platforms.query('platform == "XOne"')['user_score']
PC_userscore = recent_platforms.query('platform == "PC"')['user_score']
print('Дисперсия оценок по XOne',np.var(XOne_userscore), '\nДисперсия оценок по PC', np.var(PC_userscore))
# Out:
# Дисперсия оценок по XOne 1.8965188383045533
# Дисперсия оценок по PC 2.7569952398906565

# %% [markdown]
# Дисперсии не равны, значит значение параметра equal_var=False. Так же посмотрим на распределение каждой выборки.

# %%
XOne_userscore.hist();

# %%
PC_userscore.hist();

# %% [markdown]
# Распределение обеих выборок имеет одинаковый вид: не нормальный, унимодальный. Большая часть оценок на обеих выборках сконцентрирована в районе примерно 7,4

# %% [markdown]
# Сформулируем гипотезы и перейдем к их проверке.

# %% [markdown]
# <a id='p5s2'></a>
# ### Гипотеза 1
#
# Hо: средние пользовательские рейтинги платформ XOne и PС равны
# H1: средние пользовательские рейтинги платформ XOne и PС не равны.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера VERS#1<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Нулевая и альтернативная гипотезы сформулированы корректно👍

# %%
XOne_userscore = XOne_userscore.dropna()
PC_userscore = PC_userscore.dropna()

# %%
alpha =.05
results = st.ttest_ind(XOne_userscore, PC_userscore, equal_var = False)

print('p-value:', results.pvalue)
if results.pvalue < alpha:
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-value: 0.5489537965134912
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# **Вывод:** статистически значимых различий в пользовтательских оценках XOne и PC нет.
# **Отвергаем H1**

# %% [markdown]
# <a id='p5s2'></a>
# ### Гипотеза 2
# Hо: средние пользовательские рейтинги жанров `Action` и `Sports` равны
# H1: средние пользовательские рейтинги жанров `Action` и `Sports` не равны.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера VERS#1<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Нулевая и альтернативная гипотезы сформулированы корректно👍

# %%
action_userscore = recent_platforms.query('genre == "Action"')['user_score'].dropna()
sports_userscore = recent_platforms.query('genre == "Sports"')['user_score'].dropna()
print('Дисперсия оценок по Action',np.var(action_userscore), '\nДисперсия оценок по Sports', np.var(sports_userscore))
# Out:
# Дисперсия оценок по Action 1.8854720340439228
# Дисперсия оценок по Sports 3.007388297172914

# %%
action_userscore.hist();

# %%
sports_userscore.hist();

# %% [markdown]
# Дисперсии различны, как и распределение оценок на гистограммах.

# %%
alpha =.05
results = st.ttest_ind(action_userscore, sports_userscore, equal_var = False)

print('p-value:', results.pvalue)
if results.pvalue < alpha:
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-value: 4.24307776572644e-20
# Отвергаем нулевую гипотезу

# %% [markdown]
# **Вывод:** p-value получилось меньше 0,05, что значит что есть статистически значимые различия между средними двух выборок.
# **Отвергаем Hо**

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера VERS#1<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Гипотезы проверены верно 🤗. Для общего изучения данной темы могу порекомендовать видео,где спикер максимально простым языком объясняет процесс тестирования https://www.youtube.com/watch?v=SmReaN-Kn-g (в плейлисте это видео идет под номером 5, можно далее посмотреть номер 6 и 7).

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента<a class="tocSkip"></h2>
#
# С ютуб каналом Глеба я уже знаком, но все равно спасибо😊
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера VERS#2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# 🤗🤗🤗

# %% [markdown]
# <a id='p6s1'></a>
# ## Общий вывод

# %% [markdown]
# Для работы были предоставлены данные по продажам игр на разных платформах с 1980 по 2016 год. Мы выяснили, что активный рост всей игровой индустрии в целом начался примерно с 1994 года, что совпадает с годом выпуска PlayStation (3 декабря 1994 г). Так же начиная с этого года резко сократилось количество nan значений в наших данных по оценкам.
#
# Так же после 2009 года после `резкого роста` наблюдается такой же `резкий спад` по продажам, что можно связать с мировым экономическим кризимом 2008 года и ростопм популярности мобильного гейминга и мобильных девайсов в целом с 2012 года.
#
# `Средняя продолжительность жизни платформы` составляет 8-10 лет, но производители учитывают падение продаж на платформах и выпускают новые, более современные, платформы за несколько лет до полного падения продаж по старым поклоениям, что сокращает цикл обновления в среднем до 5-6 лет.
#
# `Наиболее популярными игровыми жанрами` по медианным значениям в рассматриваемый период с 2012 по 2016 г. в которых продается наибольшее количество копий являются жанры `Shooter, Sports и Platform`. Но жанр `Action` продал суммарно наибольшее количество копий благодаря очень успешным проектам, которые выпускались на многих платфорамх и продались в очень большом количестве.
#
# `Отзывы критиков` в виду своей большей экспертности влияет на покупку игр, чего не скажешь об `отзывах игроков`: конечно можно увидеть некоторую корреляцию между отзывами игроков и продажами, но все же корреляция значительно ниже.
#
# `По продажам` по регионам можно выделить платформу `PS4` – эта платформа пришла на смену очень популярной платформе `PS3` и находится еще в начале цикла своей жизни. Так же эта платформа интересна для пользователей `всех 3-х регионов.`
#
# `Наиболее продающий возрастной рейтинг – M («Mature»)`, что говорит о том, что наиболее популярная аудитория является совершеннолетней (в разных регионах совершеннолетие наступает в разный возраст, но `M` обозначает возраст "от 17 лет").
# `2` и `3` место по продажам имеют рейтинги `«E» («Everyone»)` и `«E10+» («Everyone 10 and older»)`. Эти возрастные рейтинги имеют уже меньше продаж, чем `M`, но их не стоит игнорировать.
# Также в данных есть отдельная категория, которая никак не заполнена, но отбрасывать данные по продажам этой категории неправильно. Известно, что игры с неуказанной возрастной категорией очень хорошо продаются в `Японии`: продажи по этой категории даже превосходят суммарные продажи по всем остальным возрастным категориям в `Японии`
#
# Также стоить учесть, что игры некоторых платформ вообще не продаются в некоторых регионах. Это важно учитывать при рекламных кампаниях. Так `игры X360 не имеют продаж в Японии`, `XOne продается только в Америке`, а `PSP и PSV не имеют продажи в Америке и Европе`
#
# В ходе исследования мы проверили `2 гипотезы`:
#
# `Опровергли` гипотезу о различии пользовательских рейтингов для платформ `XOne и PC`.
#
# `Подтвердили` гипотезу о различии пользовательских рейтингов жанров `Action и Sports`.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера VERS#1 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b>
#
# Хорошо, что представлен детальный вывод и рекомендации.👌  В аналитическом исследовании важно указывать понятный и развёрнутый вывод, ведь он раскрывает для заказчика всю твою проделанную работу и за что он платит деньги. Даже если ему не интересен весь процесс исследования, то в отчёт он заглянет обязательно. Ты молодец!

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# **Общий вывод по проекту VERS#1**
#
# Руслан, спасибо за твой проект! Тобою выполнен большой объем работы, все пункты работы соблюдены; оформление, комментарии и выводы представлены, ты большой молодец! Существует несколько важных моментов, которые можно было бы улучшить, рекомендации будут ниже в комментариях.
#
# **Отдельно подчеркнуть положительные стороны проделанной работы🙂:**
#
#
# * Работа выполнена логично, по ходу выполнения присутствуют пояснения благодаря которым понятен ход решения каждого этапа.
# * Тобой была активна использована визуализация на большом количестве этапов проекта. Здорово, что ты пользуешься данным инструментом.
# * На разных шагах проекта ты предлагал очень интересные решения и методы для их реализации: разработаны функции для вывода общей информации по набору данных и т.п. Отличная работа!
#
#
# **На что стоит обратить внимание🤓**:
#
# * Следует доработать итоговый вывод на основании обновленного анализа.
# * Скорректировать актуальный период.
# * Доработать боксплот.
# * В анализе влияния оценок на продажи использовать данные за актуальный период, рассчитать коэффициенты корреляции и построить диаграммы рассеивания для остальных перспективных платформ отдельно.
# * В анализе возрастных рейтингов необходимо учесть значения без рейтинга.
# * Остальные рекомендации ты найдешь в моих комментариях!
#
#
# **Желаю удачи и жду твой проект на повторное ревью!**😉

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# **Общий вывод по VERS#2**
#
# Руслан, спасибо за внесенные корректировки, ты отлично поработал, на текущий момент доработано примерно 99% проекта👍👍👍. Осталось изменить решение по выделению актуального периода и проект будет завершенным.
#
#
# **Желаю удачи и ожидаю проект на финальное ревью!**😉

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# **Общий вывод по проверке VERS#3**
#
# Руслан, спасибо за проделанную работу. Ты плодотворно поработал над данным проектом, учел рекомендации и довел работу до конца👍👍👍
# Желаю удачи и успеха в освоение дальнейшей учебной программы!😉
